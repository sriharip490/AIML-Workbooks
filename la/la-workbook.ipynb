# %% [markdown]
# # Linear Algebra

# %%
import numpy as np;
import pandas as pd;

# %%
a = np.array([
    [ 1, 2, 3 ],
    [ 4, 5, 6 ],
    [8, 9, 10 ]
])
print(f"Matrix A ->\n{a}")

# %%
print(f"a shape -> {a.shape}")
print(f"a dimension -> {a.ndim}")

# %%
df = pd.DataFrame(a)
